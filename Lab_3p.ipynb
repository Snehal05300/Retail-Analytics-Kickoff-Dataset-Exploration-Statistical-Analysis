# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("C:\ITvedant\Data Manipulation\Retail_Dataset_Modified.csv")
print("data loaded successfully")

# %%
df.head()
#head() method returns the first n rows of the DataFrame. By default, it returns the first 5 rows, but you can specify a different number by passing an argument to the method.

# %%
df.tail()
#tail() method returns the last n rows of the DataFrame. By default, it returns the last 5 rows, but you can specify a different number by passing an argument to the method.

# %%
df.shape()
#shape attribute returns a tuple representing the dimensions of the DataFrame. It provides the number of rows and columns in the DataFrame.

# %%
df.columns()
#columns attribute returns the column labels of the DataFrame. It provides a list of all the column names present in the DataFrame.

# %%
df.info()
#info() method provides a concise summary of the DataFrame, including the number of non-null entries, data types, and memory usage.

# %%
df.dtypes
#dtypes attribute returns the data types of each column in the DataFrame. It helps to understand the type of data stored in each column, such as integers, floats, strings, etc.

# %%
df.describe()
#gives sum, mean, std, min, max, 25%, 50%, 75% values of the data

# %%
df.sample(5)
#sample() method returns a random sample of rows from the DataFrame. By default, it returns a single row, but you can specify the number of rows to sample by passing an argument to the method.
#hyp

# %%
df.isnull().sum()
#null values detection
#checks whether the value is null(False) or not null(True)

# %%
#null value handling
1. Drop
2. replace(in categorical data-mode , in numerical data-mean/median)

# %%
df.unique()
#unique() method returns the unique values present in a column of the DataFrame. It helps to identify the distinct values in a specific column.

# %%
df.value_counts
#value_counts() method returns a Series containing the counts of unique values in a column of the DataFrame. It provides the frequency of each distinct value in the specified column.
#counting of unique values in a column
#unique values repeated in a column

# %%
df.iloc()
#iloc is use to give rows and columns based on index position
#loc is used to give rows and columns based on index label

# %%
df.sort_values
#by which column you want to sort
#sort_values() method is used to sort the DataFrame by one or more columns. It allows you to specify the column(s) to sort by and the sorting order (ascending or descending).
# ascending=True (default) for ascending order, ascending=False for descending order.

# %%
df.nlargest()
#nlargest() method returns the n largest values from a column of the DataFrame. It allows you to specify the number of largest values to retrieve and the column to consider for comparison.

# %%
len(df)
#len() function returns the number of rows in the DataFrame. It provides the total count of entries in the DataFrame.

# %%
coerce
#coerce is an argument used in certain pandas functions, such as pd.to_numeric() or pd.to_datetime(), to handle errors during data type conversion. When coerce is set to True, any values that cannot be converted to the desired data type will be replaced with NaN (Not a Number) instead of raising an error. This allows for smoother handling of invalid or incompatible data during the conversion process.
#converts forcefully error generated values into unique values

# %%
to.numeric()
# Converts a column to numeric type, with error handling
#this method coverts data into numeric values.
